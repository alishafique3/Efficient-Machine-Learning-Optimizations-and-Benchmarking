# %% [markdown]
# <a href="https://colab.research.google.com/github/alishafique3/Efficient-Machine-Learning_Optimizations-and-Benchmarking/blob/main/Fire_Classification_Part_2_Cluster_Quantization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fire and Smoke Detection Using CNN
# The base code for model training and dataset is provided in the [blog](https://www.pyimagesearch.com/2019/11/18/fire-and-smoke-detection-with-keras-and-deep-learning/) at Pyimagesearch by Adrian Rosebrock. This project has contributed to the following:
#
#
# 1.   Model training is modified for pruning, clustering, and collaborative optimizations.
# 2.   Post-Training optimization
# 3. Benchmarking in Android device

# %%
# !pip install numpy==1.23
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting numpy==1.23
#   Downloading numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 59.1 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# Successfully installed numpy-1.23.0

# %%
# !pip install -q tensorflow-model-optimization
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 17.2 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Import Libraries and Neural Network Model Class

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.test.gpu_device_name())
# Out:
# 2.12.0
# /device:GPU:0

# %%
# import the necessary packages
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SeparableConv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

class FireDetectionNet:
	@staticmethod
	def build(width, height, depth, classes):
		# initialize the model along with the input shape to be
		# "channels last" and the channels dimension itself
		model = Sequential()
		inputShape = (height, width, depth)
		chanDim = -1

		# CONV => RELU => POOL
		model.add(SeparableConv2D(16, (7, 7), padding="same",
			input_shape=inputShape))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))

		# CONV => RELU => POOL
		model.add(SeparableConv2D(32, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))

		# (CONV => RELU) * 2 => POOL
		model.add(SeparableConv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(SeparableConv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))

		# first set of FC => RELU layers
		model.add(Flatten())
		model.add(Dense(128))
		model.add(Activation("relu"))
		model.add(BatchNormalization())
		model.add(Dropout(0.5))

		# second set of FC => RELU layers
		model.add(Dense(128))
		model.add(Activation("relu"))
		model.add(BatchNormalization())
		model.add(Dropout(0.5))

		# softmax classifier
		model.add(Dense(classes))
		model.add(Activation("softmax"))

		# return the constructed network architecture
		return model

# %% [markdown]
# ##Import Data from Google Drive

# %%
# initialize the path to the fire and non-fire dataset directories
FIRE_PATH = '/content/drive/My Drive/Colab Notebooks/Robbery_Accident_Fire_Database2/Fire'
NON_FIRE_PATH = '/content/drive/My Drive/Colab Notebooks/spatial_envelope_256x256_static_8outdoorcategories'

# initialize the class labels in the dataset
CLASSES = ["Non-Fire", "Fire"]

# define the size of the training and testing split
TRAIN_SPLIT = 0.75
TEST_SPLIT = 0.25

# define the initial learning rate, batch size, and number of epochs
INIT_LR = 1e-2
BATCH_SIZE = 64
NUM_EPOCHS = 50

SAMPLE_SIZE = 50

# %%
# set the matplotlib backend so figures can be saved in the background
import matplotlib
matplotlib.use("Agg")

# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import sys

def load_dataset(datasetPath):
	# grab the paths to all images in our dataset directory, then
	# initialize our lists of images
	imagePaths = list(paths.list_images(datasetPath))
	data = []

	# loop over the image paths
	for imagePath in imagePaths:
		# load the image and resize it to be a fixed 128x128 pixels,
		# ignoring aspect ratio
		image = cv2.imread(imagePath)
		image = cv2.resize(image, (128, 128))

		# add the image to the data lists
		data.append(image)

	# return the data list as a NumPy array
	return np.array(data, dtype="float32")

# load the fire and non-fire images
print("[INFO] loading data...")
fireData = load_dataset( FIRE_PATH)
nonFireData = load_dataset( NON_FIRE_PATH)
print("[INFO] Completed")
# Out:
# [INFO] loading data...
# [INFO] Completed

# %% [markdown]
# ##Preprocessing and Exploring Dataset

# %%
print(fireData.shape)
print(nonFireData.shape)
# Out:
# (1315, 128, 128, 3)
# (2693, 128, 128, 3)

# %%
# construct the class labels for the data
fireLabels = np.ones((fireData.shape[0],))
nonFireLabels = np.zeros((nonFireData.shape[0],))
# stack the fire data with the non-fire data, then scale the data
# to the range [0, 1]
data = np.vstack([fireData, nonFireData])
labels = np.hstack([fireLabels, nonFireLabels])

# %%
data /= 255
# perform one-hot encoding on the labels and account for skew in the
# labeled data
labels = to_categorical(labels, num_classes=2)

# %%
print(data.shape)
print(labels.shape)
print(labels[1:])
# Out:
# (4008, 128, 128, 3)
# (4008, 2)
# [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]

# %%
# construct the training and testing split
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size= TEST_SPLIT, random_state=42)

# %%
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (3006, 128, 128, 3)
# (3006, 2)
# (1002, 128, 128, 3)
# (1002, 2)

# %% [markdown]
# ##Training Model

# %%
# initialize the optimizer and model
print("[INFO] compiling model...")
opt = tf.keras.optimizers.Adam(learning_rate=1e-4)

model = FireDetectionNet.build(width=128, height=128, depth=3,
	classes=2)
model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])
# Out:
# [INFO] compiling model...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  separable_conv2d (Separable  (None, 128, 128, 16)     211
#  Conv2D)
#
#  activation (Activation)     (None, 128, 128, 16)      0
#
#  batch_normalization (BatchN  (None, 128, 128, 16)     64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  separable_conv2d_1 (Separab  (None, 64, 64, 32)       688
#  leConv2D)
#
#  activation_1 (Activation)   (None, 64, 64, 32)        0
#
#  batch_normalization_1 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  separable_conv2d_2 (Separab  (None, 32, 32, 64)       2400
#  leConv2D)
#
#  activation_2 (Activation)   (None, 32, 32, 64)        0
#
#  batch_normalization_2 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  separable_conv2d_3 (Separab  (None, 32, 32, 64)       4736
#  leConv2D)
#
#  activation_3 (Activation)   (None, 32, 32, 64)        0
#
#  batch_normalization_3 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  activation_4 (Activation)   (None, 128)               0
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  activation_5 (Activation)   (None, 128)               0
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 2)                 258
#
#  activation_6 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 2,123,813
# Trainable params: 2,122,949
# Non-trainable params: 864
# _________________________________________________________________

# %%
# train the network
print("[INFO] training network...")
H = model.fit(
  trainX, trainY, batch_size= BATCH_SIZE,
	validation_data=(testX, testY),
	steps_per_epoch=trainX.shape[0] //  BATCH_SIZE,
	epochs= NUM_EPOCHS,
	verbose=1)
# Out:
# [INFO] training network...
# Epoch 1/50
# 46/46 [==============================] - 20s 62ms/step - loss: 0.8008 - accuracy: 0.6556 - val_loss: 0.6864 - val_accuracy: 0.6507
# Epoch 2/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.6014 - accuracy: 0.7546 - val_loss: 0.6555 - val_accuracy: 0.6507
# Epoch 3/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.5309 - accuracy: 0.8005 - val_loss: 0.6698 - val_accuracy: 0.6507
# Epoch 4/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.4621 - accuracy: 0.8375 - val_loss: 0.7112 - val_accuracy: 0.6507
# Epoch 5/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.4177 - accuracy: 0.8542 - val_loss: 0.7924 - val_accuracy: 0.6507
# Epoch 6/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.3772 - accuracy: 0.8708 - val_loss: 1.0106 - val_accuracy: 0.6507
# Epoch 7/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.3211 - accuracy: 0.9001 - val_loss: 1.2321 - val_accuracy: 0.6507
# Epoch 8/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.2881 - accuracy: 0.9055 - val_loss: 1.5338 - val_accuracy: 0.6507
# Epoch 9/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.2638 - accuracy: 0.9235 - val_loss: 1.5968 - val_accuracy: 0.6507
# Epoch 10/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.2216 - accuracy: 0.9327 - val_loss: 1.4030 - val_accuracy: 0.6507
# Epoch 11/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.1818 - accuracy: 0.9548 - val_loss: 1.0580 - val_accuracy: 0.6517
# Epoch 12/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.1585 - accuracy: 0.9565 - val_loss: 0.8484 - val_accuracy: 0.6647
# Epoch 13/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.1461 - accuracy: 0.9589 - val_loss: 0.7136 - val_accuracy: 0.7016
# Epoch 14/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.1311 - accuracy: 0.9704 - val_loss: 0.5476 - val_accuracy: 0.7615
# Epoch 15/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.1114 - accuracy: 0.9762 - val_loss: 0.4482 - val_accuracy: 0.7994
# Epoch 16/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.1000 - accuracy: 0.9816 - val_loss: 0.3836 - val_accuracy: 0.8433
# Epoch 17/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0818 - accuracy: 0.9830 - val_loss: 0.3934 - val_accuracy: 0.8403
# Epoch 18/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0820 - accuracy: 0.9833 - val_loss: 0.4338 - val_accuracy: 0.8293
# Epoch 19/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0717 - accuracy: 0.9844 - val_loss: 0.3714 - val_accuracy: 0.8792
# Epoch 20/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0660 - accuracy: 0.9867 - val_loss: 0.3950 - val_accuracy: 0.8752
# Epoch 21/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0536 - accuracy: 0.9918 - val_loss: 0.4230 - val_accuracy: 0.8523
# Epoch 22/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0486 - accuracy: 0.9932 - val_loss: 0.4190 - val_accuracy: 0.8643
# Epoch 23/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0472 - accuracy: 0.9922 - val_loss: 0.4448 - val_accuracy: 0.8533
# Epoch 24/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0498 - accuracy: 0.9912 - val_loss: 0.4928 - val_accuracy: 0.8363
# Epoch 25/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0432 - accuracy: 0.9939 - val_loss: 0.4275 - val_accuracy: 0.8623
# Epoch 26/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0324 - accuracy: 0.9959 - val_loss: 0.4315 - val_accuracy: 0.8693
# Epoch 27/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0333 - accuracy: 0.9966 - val_loss: 0.4339 - val_accuracy: 0.8703
# Epoch 28/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0370 - accuracy: 0.9942 - val_loss: 0.4548 - val_accuracy: 0.8513
# Epoch 29/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0276 - accuracy: 0.9976 - val_loss: 0.4512 - val_accuracy: 0.8812
# Epoch 30/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0265 - accuracy: 0.9966 - val_loss: 0.4469 - val_accuracy: 0.8673
# Epoch 31/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0215 - accuracy: 0.9966 - val_loss: 0.4416 - val_accuracy: 0.8663
# Epoch 32/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0227 - accuracy: 0.9983 - val_loss: 0.4656 - val_accuracy: 0.8643
# Epoch 33/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0209 - accuracy: 0.9976 - val_loss: 0.4524 - val_accuracy: 0.8703
# Epoch 34/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0168 - accuracy: 0.9983 - val_loss: 0.4806 - val_accuracy: 0.8573
# Epoch 35/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0178 - accuracy: 0.9983 - val_loss: 0.4736 - val_accuracy: 0.8583
# Epoch 36/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0147 - accuracy: 0.9997 - val_loss: 0.4736 - val_accuracy: 0.8623
# Epoch 37/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0122 - accuracy: 0.9997 - val_loss: 0.4855 - val_accuracy: 0.8573
# Epoch 38/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0173 - accuracy: 0.9973 - val_loss: 0.5373 - val_accuracy: 0.8443
# Epoch 39/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0160 - accuracy: 0.9973 - val_loss: 0.4777 - val_accuracy: 0.8723
# Epoch 40/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.5089 - val_accuracy: 0.8593
# Epoch 41/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0135 - accuracy: 0.9983 - val_loss: 0.4999 - val_accuracy: 0.8583
# Epoch 42/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0129 - accuracy: 0.9983 - val_loss: 0.4993 - val_accuracy: 0.8693
# Epoch 43/50
# 46/46 [==============================] - 2s 49ms/step - loss: 0.0108 - accuracy: 0.9990 - val_loss: 0.5070 - val_accuracy: 0.8613
# Epoch 44/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0122 - accuracy: 0.9990 - val_loss: 0.5083 - val_accuracy: 0.8762
# Epoch 45/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0108 - accuracy: 0.9997 - val_loss: 0.6130 - val_accuracy: 0.8383
# Epoch 46/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0140 - accuracy: 0.9980 - val_loss: 0.5237 - val_accuracy: 0.8673
# Epoch 47/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0122 - accuracy: 0.9997 - val_loss: 0.5109 - val_accuracy: 0.8653
# Epoch 48/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0122 - accuracy: 0.9986 - val_loss: 0.5183 - val_accuracy: 0.8733
# Epoch 49/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0115 - accuracy: 0.9993 - val_loss: 0.4982 - val_accuracy: 0.8653
# Epoch 50/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0081 - accuracy: 0.9997 - val_loss: 0.5404 - val_accuracy: 0.8693

# %% [markdown]
# ##Exploring Predictions

# %%
# evaluate the network and show a classification report
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size= BATCH_SIZE)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names= CLASSES))

# %matplotlib inline
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(testX[i], cmap=plt.cm.binary)
    if testY[i][0] == 1:
      if predictions[i][0] > 0.5:
        plt.xlabel("Non-Fire", color='green')
      else:
        plt.xlabel("Non-Fire", color='red')
    else:
      if predictions[i][1] > 0.5:
        plt.xlabel("Fire", color='green')
      else:
        plt.xlabel("Fire", color='red')

plt.show()
# Out:
# [INFO] evaluating network...
# 16/16 [==============================] - 0s 22ms/step
#               precision    recall  f1-score   support
#
#     Non-Fire       0.87      0.94      0.90       652
#         Fire       0.86      0.74      0.80       350
#
#     accuracy                           0.87      1002
#    macro avg       0.87      0.84      0.85      1002
# weighted avg       0.87      0.87      0.87      1002

# %%
import tensorflow_model_optimization as tfmot

cluster_weights = tfmot.clustering.keras.cluster_weights
CentroidInitialization = tfmot.clustering.keras.CentroidInitialization

clustering_params = {
  'number_of_clusters': 8,
  'cluster_centroids_init': CentroidInitialization.KMEANS_PLUS_PLUS,
  'cluster_per_channel': True,
}

clustered_model = cluster_weights(model, **clustering_params)

# Use smaller learning rate for fine-tuning
opt = tf.keras.optimizers.Adam(learning_rate=1e-5)

clustered_model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])

clustered_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cluster_separable_conv2d (C  (None, 128, 128, 16)     267
#  lusterWeights)
#
#  cluster_activation (Cluster  (None, 128, 128, 16)     0
#  Weights)
#
#  cluster_batch_normalization  (None, 128, 128, 16)     64
#   (ClusterWeights)
#
#  cluster_max_pooling2d (Clus  (None, 64, 64, 16)       0
#  terWeights)
#
#  cluster_separable_conv2d_1   (None, 64, 64, 32)       1208
#  (ClusterWeights)
#
#  cluster_activation_1 (Clust  (None, 64, 64, 32)       0
#  erWeights)
#
#  cluster_batch_normalization  (None, 64, 64, 32)       128
#  _1 (ClusterWeights)
#
#  cluster_max_pooling2d_1 (Cl  (None, 32, 32, 32)       0
#  usterWeights)
#
#  cluster_separable_conv2d_2   (None, 32, 32, 64)       4456
#  (ClusterWeights)
#
#  cluster_activation_2 (Clust  (None, 32, 32, 64)       0
#  erWeights)
#
#  cluster_batch_normalization  (None, 32, 32, 64)       256
#  _2 (ClusterWeights)
#
#  cluster_separable_conv2d_3   (None, 32, 32, 64)       8840
#  (ClusterWeights)
#
#  cluster_activation_3 (Clust  (None, 32, 32, 64)       0
#  erWeights)
#
#  cluster_batch_normalization  (None, 32, 32, 64)       256
#  _3 (ClusterWeights)
#
#  cluster_max_pooling2d_2 (Cl  (None, 16, 16, 64)       0
#  usterWeights)
#
#  cluster_flatten (ClusterWei  (None, 16384)            0
#  ghts)
#
#  cluster_dense (ClusterWeigh  (None, 128)              4194440
#  ts)
#
#  cluster_activation_4 (Clust  (None, 128)              0
#  erWeights)
#
#  cluster_batch_normalization  (None, 128)              512
#  _4 (ClusterWeights)
#
#  cluster_dropout (ClusterWei  (None, 128)              0
#  ghts)
#
#  cluster_dense_1 (ClusterWei  (None, 128)              32904
#  ghts)
#
#  cluster_activation_5 (Clust  (None, 128)              0
#  erWeights)
#
#  cluster_batch_normalization  (None, 128)              512
#  _5 (ClusterWeights)
#
#  cluster_dropout_1 (ClusterW  (None, 128)              0
#  eights)
#
#  cluster_dense_2 (ClusterWei  (None, 2)                522
#  ghts)
#
#  cluster_activation_6 (Clust  (None, 2)                0
#  erWeights)
#
# =================================================================
# Total params: 4,244,365
# Trainable params: 2,123,005
# Non-trainable params: 2,121,360
# _________________________________________________________________

# %%
# train the network
print("[INFO] training network...")
H = clustered_model.fit(
  trainX, trainY, batch_size= BATCH_SIZE,
	validation_data=(testX, testY),
	steps_per_epoch=trainX.shape[0] //  BATCH_SIZE,
	epochs= 5,
	verbose=1)
# Out:
# [INFO] training network...
# Epoch 1/5
# 46/46 [==============================] - 11s 63ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.5748 - val_accuracy: 0.8453
# Epoch 2/5
# 46/46 [==============================] - 2s 46ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.6110 - val_accuracy: 0.8433
# Epoch 3/5
# 46/46 [==============================] - 2s 47ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6350 - val_accuracy: 0.8483
# Epoch 4/5
# 46/46 [==============================] - 2s 52ms/step - loss: 8.5751e-04 - accuracy: 1.0000 - val_loss: 0.6475 - val_accuracy: 0.8443
# Epoch 5/5
# 46/46 [==============================] - 2s 48ms/step - loss: 6.8398e-04 - accuracy: 1.0000 - val_loss: 0.6679 - val_accuracy: 0.8443

# %%
def print_model_weight_clusters(model):

    for layer in model.layers:
        if isinstance(layer, tf.keras.layers.Wrapper):
            weights = layer.trainable_weights
        else:
            weights = layer.weights
        for weight in weights:
            # ignore auxiliary quantization weights
            if "quantize_layer" in weight.name:
                continue
            if "kernel" in weight.name:
                unique_count = len(np.unique(weight))
                print(
                    f"{layer.name}/{weight.name}: {unique_count} clusters "
                )

# %%
stripped_clustered_model = tfmot.clustering.keras.strip_clustering(clustered_model)

print_model_weight_clusters(stripped_clustered_model)
# Out:
# separable_conv2d/depthwise_kernel:0: 147 clusters
# separable_conv2d/pointwise_kernel:0: 8 clusters
# separable_conv2d_1/depthwise_kernel:0: 144 clusters
# separable_conv2d_1/pointwise_kernel:0: 8 clusters
# separable_conv2d_2/depthwise_kernel:0: 288 clusters
# separable_conv2d_2/pointwise_kernel:0: 8 clusters
# separable_conv2d_3/depthwise_kernel:0: 576 clusters
# separable_conv2d_3/pointwise_kernel:0: 8 clusters
# dense/kernel:0: 8 clusters
# dense_1/kernel:0: 8 clusters
# dense_2/kernel:0: 8 clusters

# %%
import os
import tempfile

# %%
def get_gzipped_model_size(file):
  # Returns size of gzipped model, in bytes.
  import os
  import zipfile

  _, zipped_file = tempfile.mkstemp('.zip')
  with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
    f.write(file)

  return os.path.getsize(zipped_file)

# %%
converter4 = tf.lite.TFLiteConverter.from_keras_model(stripped_clustered_model)
converter4.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter4.convert()

_, quantized_and_clustered_tflite_file = tempfile.mkstemp('.tflite')

with open(quantized_and_clustered_tflite_file, 'wb') as f:
  f.write(tflite_quant_model)

print('Saved quantized and clustered TFLite model to:', quantized_and_clustered_tflite_file)

print("Size of gzipped clustered and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(quantized_and_clustered_tflite_file)))
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# Saved quantized and clustered TFLite model to: /tmp/tmpvj4oa0mv.tflite
# Size of gzipped clustered and quantized TFlite model: 902170.00 bytes
