# %% [markdown]
# <a href="https://colab.research.google.com/github/alishafique3/Efficient-Machine-Learning_Optimizations-and-Benchmarking/blob/main/Fire_Classification_Part_3_Prune_Quantization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fire and NonFire Classification Using CNN
# The base code for model training and dataset is provided in the [blog](https://www.pyimagesearch.com/2019/11/18/fire-and-smoke-detection-with-keras-and-deep-learning/) at Pyimagesearch by Adrian Rosebrock. This project has contributed to the following:
#
#
# 1.   Model training is modified for pruning, clustering, and collaborative optimizations.
# 2.   Post-Training optimization
# 3. Benchmarking in Android device

# %%
# !pip install numpy==1.23
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting numpy==1.23
#   Downloading numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 40.7 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# Successfully installed numpy-1.23.0

# %%
# !pip install -q tensorflow-model-optimization
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 10.1 MB/s eta 0:00:00

# %%
import numpy
numpy.version.version
# Out:
# '1.23.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Import Libraries and Neural Network Model Class

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.test.gpu_device_name())
# Out:
# 2.12.0
# /device:GPU:0

# %%
# import the necessary packages
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SeparableConv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

class FireDetectionNet:
	@staticmethod
	def build(width, height, depth, classes):
		# initialize the model along with the input shape to be
		# "channels last" and the channels dimension itself
		model = Sequential()
		inputShape = (height, width, depth)
		chanDim = -1

		# CONV => RELU => POOL
		model.add(SeparableConv2D(16, (7, 7), padding="same",
			input_shape=inputShape))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))

		# CONV => RELU => POOL
		model.add(SeparableConv2D(32, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))

		# (CONV => RELU) * 2 => POOL
		model.add(SeparableConv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(SeparableConv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))

		# first set of FC => RELU layers
		model.add(Flatten())
		model.add(Dense(128))
		model.add(Activation("relu"))
		model.add(BatchNormalization())
		model.add(Dropout(0.5))

		# second set of FC => RELU layers
		model.add(Dense(128))
		model.add(Activation("relu"))
		model.add(BatchNormalization())
		model.add(Dropout(0.5))

		# softmax classifier
		model.add(Dense(classes))
		model.add(Activation("softmax"))

		# return the constructed network architecture
		return model

# %% [markdown]
# ##Import Data from Google Drive

# %%
# initialize the path to the fire and non-fire dataset directories
FIRE_PATH = '/content/drive/My Drive/Colab Notebooks/Robbery_Accident_Fire_Database2/Fire'
NON_FIRE_PATH = '/content/drive/My Drive/Colab Notebooks/spatial_envelope_256x256_static_8outdoorcategories'

# initialize the class labels in the dataset
CLASSES = ["Non-Fire", "Fire"]

# define the size of the training and testing split
TRAIN_SPLIT = 0.75
TEST_SPLIT = 0.25

# define the initial learning rate, batch size, and number of epochs
INIT_LR = 1e-2
BATCH_SIZE = 64
NUM_EPOCHS = 50

SAMPLE_SIZE = 50

# %%
# set the matplotlib backend so figures can be saved in the background
import matplotlib
matplotlib.use("Agg")

# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import sys

def load_dataset(datasetPath):
	# grab the paths to all images in our dataset directory, then
	# initialize our lists of images
	imagePaths = list(paths.list_images(datasetPath))
	data = []

	# loop over the image paths
	for imagePath in imagePaths:
		# load the image and resize it to be a fixed 128x128 pixels,
		# ignoring aspect ratio
		image = cv2.imread(imagePath)
		image = cv2.resize(image, (128, 128))

		# add the image to the data lists
		data.append(image)

	# return the data list as a NumPy array
	return np.array(data, dtype="float32")

# load the fire and non-fire images
print("[INFO] loading data...")
fireData = load_dataset( FIRE_PATH)
nonFireData = load_dataset( NON_FIRE_PATH)
print("[INFO] Completed")
# Out:
# [INFO] loading data...
# [INFO] Completed

# %% [markdown]
# ##Preprocessing and Exploring Dataset

# %%
print(fireData.shape)
print(nonFireData.shape)
# Out:
# (1315, 128, 128, 3)
# (2693, 128, 128, 3)

# %%
# construct the class labels for the data
fireLabels = np.ones((fireData.shape[0],))
nonFireLabels = np.zeros((nonFireData.shape[0],))
# stack the fire data with the non-fire data, then scale the data
# to the range [0, 1]
data = np.vstack([fireData, nonFireData])
labels = np.hstack([fireLabels, nonFireLabels])

# %%
data /= 255
# perform one-hot encoding on the labels and account for skew in the
# labeled data
labels = to_categorical(labels, num_classes=2)

# %%
print(data.shape)
print(labels.shape)
print(labels[1:])
# Out:
# (4008, 128, 128, 3)
# (4008, 2)
# [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]

# %%
# construct the training and testing split
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size= TEST_SPLIT, random_state=42)

# %%
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (3006, 128, 128, 3)
# (3006, 2)
# (1002, 128, 128, 3)
# (1002, 2)

# %% [markdown]
# ##Training Model

# %%
# initialize the optimizer and model
print("[INFO] compiling model...")
opt = tf.keras.optimizers.Adam(learning_rate=1e-4)

model = FireDetectionNet.build(width=128, height=128, depth=3,
	classes=2)
model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])

# check to see if we are attempting to find an optimal learning rate
# before training for the full number of epochs
# Out:
# [INFO] compiling model...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  separable_conv2d (Separable  (None, 128, 128, 16)     211
#  Conv2D)
#
#  activation (Activation)     (None, 128, 128, 16)      0
#
#  batch_normalization (BatchN  (None, 128, 128, 16)     64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  separable_conv2d_1 (Separab  (None, 64, 64, 32)       688
#  leConv2D)
#
#  activation_1 (Activation)   (None, 64, 64, 32)        0
#
#  batch_normalization_1 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  separable_conv2d_2 (Separab  (None, 32, 32, 64)       2400
#  leConv2D)
#
#  activation_2 (Activation)   (None, 32, 32, 64)        0
#
#  batch_normalization_2 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  separable_conv2d_3 (Separab  (None, 32, 32, 64)       4736
#  leConv2D)
#
#  activation_3 (Activation)   (None, 32, 32, 64)        0
#
#  batch_normalization_3 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  activation_4 (Activation)   (None, 128)               0
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  activation_5 (Activation)   (None, 128)               0
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 2)                 258
#
#  activation_6 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 2,123,813
# Trainable params: 2,122,949
# Non-trainable params: 864
# _________________________________________________________________

# %%
# train the network
print("[INFO] training network...")
H = model.fit(
  trainX, trainY, batch_size= BATCH_SIZE,
	validation_data=(testX, testY),
	steps_per_epoch=trainX.shape[0] //  BATCH_SIZE,
	epochs= NUM_EPOCHS,
	verbose=1)
# Out:
# [INFO] training network...
# Epoch 1/50
# 46/46 [==============================] - 20s 54ms/step - loss: 0.7488 - accuracy: 0.6760 - val_loss: 0.6539 - val_accuracy: 0.6507
# Epoch 2/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.5988 - accuracy: 0.7692 - val_loss: 0.6617 - val_accuracy: 0.6507
# Epoch 3/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5194 - accuracy: 0.8103 - val_loss: 0.6794 - val_accuracy: 0.6507
# Epoch 4/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.4448 - accuracy: 0.8341 - val_loss: 0.6901 - val_accuracy: 0.6507
# Epoch 5/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.3842 - accuracy: 0.8678 - val_loss: 0.7426 - val_accuracy: 0.6507
# Epoch 6/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.3358 - accuracy: 0.8885 - val_loss: 0.7857 - val_accuracy: 0.6507
# Epoch 7/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.3089 - accuracy: 0.9045 - val_loss: 0.8569 - val_accuracy: 0.6507
# Epoch 8/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.2587 - accuracy: 0.9232 - val_loss: 0.9959 - val_accuracy: 0.6507
# Epoch 9/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.2463 - accuracy: 0.9286 - val_loss: 0.9840 - val_accuracy: 0.6507
# Epoch 10/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.2226 - accuracy: 0.9388 - val_loss: 0.9860 - val_accuracy: 0.6507
# Epoch 11/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.1799 - accuracy: 0.9565 - val_loss: 0.7912 - val_accuracy: 0.6597
# Epoch 12/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.1673 - accuracy: 0.9562 - val_loss: 0.6154 - val_accuracy: 0.7216
# Epoch 13/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.1367 - accuracy: 0.9704 - val_loss: 0.5218 - val_accuracy: 0.7635
# Epoch 14/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.1224 - accuracy: 0.9793 - val_loss: 0.4400 - val_accuracy: 0.8094
# Epoch 15/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0996 - accuracy: 0.9827 - val_loss: 0.3754 - val_accuracy: 0.8443
# Epoch 16/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0976 - accuracy: 0.9803 - val_loss: 0.3406 - val_accuracy: 0.8643
# Epoch 17/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0853 - accuracy: 0.9837 - val_loss: 0.3333 - val_accuracy: 0.8713
# Epoch 18/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0784 - accuracy: 0.9857 - val_loss: 0.3277 - val_accuracy: 0.8772
# Epoch 19/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0757 - accuracy: 0.9854 - val_loss: 0.3591 - val_accuracy: 0.8693
# Epoch 20/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0666 - accuracy: 0.9905 - val_loss: 0.3953 - val_accuracy: 0.8643
# Epoch 21/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0639 - accuracy: 0.9905 - val_loss: 0.3686 - val_accuracy: 0.8782
# Epoch 22/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0482 - accuracy: 0.9942 - val_loss: 0.3698 - val_accuracy: 0.8703
# Epoch 23/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0477 - accuracy: 0.9946 - val_loss: 0.3838 - val_accuracy: 0.8653
# Epoch 24/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0446 - accuracy: 0.9949 - val_loss: 0.3730 - val_accuracy: 0.8663
# Epoch 25/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0382 - accuracy: 0.9942 - val_loss: 0.3705 - val_accuracy: 0.8772
# Epoch 26/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0361 - accuracy: 0.9966 - val_loss: 0.3985 - val_accuracy: 0.8733
# Epoch 27/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0313 - accuracy: 0.9963 - val_loss: 0.3722 - val_accuracy: 0.8752
# Epoch 28/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0329 - accuracy: 0.9966 - val_loss: 0.4066 - val_accuracy: 0.8772
# Epoch 29/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0316 - accuracy: 0.9963 - val_loss: 0.4131 - val_accuracy: 0.8663
# Epoch 30/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0273 - accuracy: 0.9973 - val_loss: 0.4099 - val_accuracy: 0.8653
# Epoch 31/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0225 - accuracy: 0.9990 - val_loss: 0.3992 - val_accuracy: 0.8743
# Epoch 32/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0241 - accuracy: 0.9973 - val_loss: 0.4126 - val_accuracy: 0.8693
# Epoch 33/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0239 - accuracy: 0.9973 - val_loss: 0.4176 - val_accuracy: 0.8733
# Epoch 34/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0224 - accuracy: 0.9983 - val_loss: 0.4299 - val_accuracy: 0.8673
# Epoch 35/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0208 - accuracy: 0.9976 - val_loss: 0.4493 - val_accuracy: 0.8633
# Epoch 36/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0196 - accuracy: 0.9976 - val_loss: 0.4311 - val_accuracy: 0.8663
# Epoch 37/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0163 - accuracy: 0.9993 - val_loss: 0.4713 - val_accuracy: 0.8583
# Epoch 38/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0161 - accuracy: 0.9986 - val_loss: 0.4469 - val_accuracy: 0.8733
# Epoch 39/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0134 - accuracy: 0.9993 - val_loss: 0.4600 - val_accuracy: 0.8613
# Epoch 40/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0147 - accuracy: 0.9993 - val_loss: 0.4319 - val_accuracy: 0.8743
# Epoch 41/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0137 - accuracy: 0.9986 - val_loss: 0.4092 - val_accuracy: 0.8762
# Epoch 42/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.4635 - val_accuracy: 0.8713
# Epoch 43/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0126 - accuracy: 0.9990 - val_loss: 0.4608 - val_accuracy: 0.8653
# Epoch 44/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0141 - accuracy: 0.9986 - val_loss: 0.4519 - val_accuracy: 0.8713
# Epoch 45/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0107 - accuracy: 0.9993 - val_loss: 0.4629 - val_accuracy: 0.8683
# Epoch 46/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0102 - accuracy: 0.9997 - val_loss: 0.4524 - val_accuracy: 0.8762
# Epoch 47/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0100 - accuracy: 0.9997 - val_loss: 0.5138 - val_accuracy: 0.8573
# Epoch 48/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0086 - accuracy: 0.9993 - val_loss: 0.4856 - val_accuracy: 0.8623
# Epoch 49/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.4528 - val_accuracy: 0.8752
# Epoch 50/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0097 - accuracy: 0.9990 - val_loss: 0.4789 - val_accuracy: 0.8693

# %% [markdown]
# ##Exploring Predictions

# %%
# evaluate the network and show a classification report
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size= BATCH_SIZE)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names= CLASSES))

# %matplotlib inline
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(testX[i], cmap=plt.cm.binary)
    if testY[i][0] == 1:
      if predictions[i][0] > 0.5:
        plt.xlabel("Non-Fire", color='green')
      else:
        plt.xlabel("Non-Fire", color='red')
    else:
      if predictions[i][1] > 0.5:
        plt.xlabel("Fire", color='green')
      else:
        plt.xlabel("Fire", color='red')

plt.show()
# Out:
# [INFO] evaluating network...
# 16/16 [==============================] - 0s 13ms/step
#               precision    recall  f1-score   support
#
#     Non-Fire       0.86      0.95      0.90       652
#         Fire       0.88      0.72      0.79       350
#
#     accuracy                           0.87      1002
#    macro avg       0.87      0.84      0.85      1002
# weighted avg       0.87      0.87      0.87      1002

# %%
import tensorflow_model_optimization as tfmot

prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.ConstantSparsity(0.5, begin_step=0, frequency=100)
  }

callbacks = [
  tfmot.sparsity.keras.UpdatePruningStep()
]

pruned_model = prune_low_magnitude(model, **pruning_params)

# Use smaller learning rate for fine-tuning
opt = tf.keras.optimizers.Adam(learning_rate=1e-5)

pruned_model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])

# %%
# train the network
print("[INFO] training network...")
H = pruned_model.fit(
  trainX, trainY, batch_size= BATCH_SIZE,
	validation_data=(testX, testY),
	steps_per_epoch=trainX.shape[0] //  BATCH_SIZE,
	epochs= 20,
	callbacks=callbacks,
	verbose=1)
# Out:
# [INFO] training network...
# Epoch 1/20
# 46/46 [==============================] - 16s 69ms/step - loss: 0.0079 - accuracy: 0.9997 - val_loss: 0.4806 - val_accuracy: 0.8723
# Epoch 2/20
# 46/46 [==============================] - 3s 55ms/step - loss: 0.0085 - accuracy: 0.9990 - val_loss: 0.4712 - val_accuracy: 0.8723
# Epoch 3/20
# 46/46 [==============================] - 2s 45ms/step - loss: 0.1687 - accuracy: 0.9419 - val_loss: 0.6950 - val_accuracy: 0.7984
# Epoch 4/20
# 46/46 [==============================] - 2s 43ms/step - loss: 0.1422 - accuracy: 0.9531 - val_loss: 0.6159 - val_accuracy: 0.8124
# Epoch 5/20
# 46/46 [==============================] - 2s 45ms/step - loss: 0.1297 - accuracy: 0.9541 - val_loss: 0.5686 - val_accuracy: 0.8234
# Epoch 6/20
# 46/46 [==============================] - 2s 45ms/step - loss: 0.1025 - accuracy: 0.9630 - val_loss: 0.5288 - val_accuracy: 0.8383
# Epoch 7/20
# 46/46 [==============================] - 2s 44ms/step - loss: 0.1067 - accuracy: 0.9640 - val_loss: 0.5102 - val_accuracy: 0.8413
# Epoch 8/20
# 46/46 [==============================] - 3s 56ms/step - loss: 0.1010 - accuracy: 0.9657 - val_loss: 0.5023 - val_accuracy: 0.8433
# Epoch 9/20
# 46/46 [==============================] - 2s 52ms/step - loss: 0.0948 - accuracy: 0.9677 - val_loss: 0.5040 - val_accuracy: 0.8463
# Epoch 10/20
# 46/46 [==============================] - 2s 45ms/step - loss: 0.0843 - accuracy: 0.9782 - val_loss: 0.4988 - val_accuracy: 0.8443
# Epoch 11/20
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0785 - accuracy: 0.9759 - val_loss: 0.4956 - val_accuracy: 0.8503
# Epoch 12/20
# 46/46 [==============================] - 2s 45ms/step - loss: 0.0790 - accuracy: 0.9752 - val_loss: 0.4957 - val_accuracy: 0.8483
# Epoch 13/20
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0740 - accuracy: 0.9772 - val_loss: 0.4911 - val_accuracy: 0.8523
# Epoch 14/20
# 46/46 [==============================] - 2s 48ms/step - loss: 0.0674 - accuracy: 0.9779 - val_loss: 0.4897 - val_accuracy: 0.8503
# Epoch 15/20
# 46/46 [==============================] - 3s 55ms/step - loss: 0.0621 - accuracy: 0.9840 - val_loss: 0.4851 - val_accuracy: 0.8503
# Epoch 16/20
# 46/46 [==============================] - 2s 48ms/step - loss: 0.0681 - accuracy: 0.9769 - val_loss: 0.4785 - val_accuracy: 0.8523
# Epoch 17/20
# 46/46 [==============================] - 2s 47ms/step - loss: 0.0606 - accuracy: 0.9803 - val_loss: 0.4864 - val_accuracy: 0.8513
# Epoch 18/20
# 46/46 [==============================] - 2s 46ms/step - loss: 0.0700 - accuracy: 0.9779 - val_loss: 0.4833 - val_accuracy: 0.8523
# Epoch 19/20
# 46/46 [==============================] - 2s 47ms/step - loss: 0.0599 - accuracy: 0.9820 - val_loss: 0.4831 - val_accuracy: 0.8533
# Epoch 20/20
# 46/46 [==============================] - 2s 46ms/step - loss: 0.0626 - accuracy: 0.9816 - val_loss: 0.4798 - val_accuracy: 0.8543

# %%
def print_model_weights_sparsity(model):

    for layer in model.layers:
        if isinstance(layer, tf.keras.layers.Wrapper):
            weights = layer.trainable_weights
        else:
            weights = layer.weights
        for weight in weights:
            # ignore auxiliary quantization weights
            if "quantize_layer" in weight.name:
                continue
            weight_size = weight.numpy().size
            zero_num = np.count_nonzero(weight == 0)
            print(
                f"{weight.name}: {zero_num/weight_size:.2%} sparsity ",
                f"({zero_num}/{weight_size})",
            )

# %%
stripped_pruned_model = tfmot.sparsity.keras.strip_pruning(pruned_model)

print_model_weights_sparsity(stripped_pruned_model)
# Out:
# separable_conv2d/depthwise_kernel:0: 0.00% sparsity  (0/147)
# separable_conv2d/pointwise_kernel:0: 50.00% sparsity  (24/48)
# separable_conv2d/bias:0: 0.00% sparsity  (0/16)
# batch_normalization/gamma:0: 0.00% sparsity  (0/16)
# batch_normalization/beta:0: 0.00% sparsity  (0/16)
# batch_normalization/moving_mean:0: 0.00% sparsity  (0/16)
# batch_normalization/moving_variance:0: 0.00% sparsity  (0/16)
# separable_conv2d_1/depthwise_kernel:0: 0.00% sparsity  (0/144)
# separable_conv2d_1/pointwise_kernel:0: 50.00% sparsity  (256/512)
# separable_conv2d_1/bias:0: 0.00% sparsity  (0/32)
# batch_normalization_1/gamma:0: 0.00% sparsity  (0/32)
# batch_normalization_1/beta:0: 0.00% sparsity  (0/32)
# batch_normalization_1/moving_mean:0: 0.00% sparsity  (0/32)
# batch_normalization_1/moving_variance:0: 0.00% sparsity  (0/32)
# separable_conv2d_2/depthwise_kernel:0: 0.00% sparsity  (0/288)
# separable_conv2d_2/pointwise_kernel:0: 50.00% sparsity  (1024/2048)
# separable_conv2d_2/bias:0: 0.00% sparsity  (0/64)
# batch_normalization_2/gamma:0: 0.00% sparsity  (0/64)
# batch_normalization_2/beta:0: 0.00% sparsity  (0/64)
# batch_normalization_2/moving_mean:0: 0.00% sparsity  (0/64)
# batch_normalization_2/moving_variance:0: 0.00% sparsity  (0/64)
# separable_conv2d_3/depthwise_kernel:0: 0.00% sparsity  (0/576)
# separable_conv2d_3/pointwise_kernel:0: 50.00% sparsity  (2048/4096)
# separable_conv2d_3/bias:0: 0.00% sparsity  (0/64)
# batch_normalization_3/gamma:0: 0.00% sparsity  (0/64)
# batch_normalization_3/beta:0: 0.00% sparsity  (0/64)
# batch_normalization_3/moving_mean:0: 0.00% sparsity  (0/64)
# batch_normalization_3/moving_variance:0: 0.00% sparsity  (0/64)
# dense/kernel:0: 50.00% sparsity  (1048576/2097152)
# dense/bias:0: 0.00% sparsity  (0/128)
# batch_normalization_4/gamma:0: 0.00% sparsity  (0/128)
# batch_normalization_4/beta:0: 0.00% sparsity  (0/128)
# batch_normalization_4/moving_mean:0: 0.00% sparsity  (0/128)
# batch_normalization_4/moving_variance:0: 0.00% sparsity  (0/128)
# dense_1/kernel:0: 50.00% sparsity  (8192/16384)
# dense_1/bias:0: 0.00% sparsity  (0/128)
# batch_normalization_5/gamma:0: 0.00% sparsity  (0/128)
# batch_normalization_5/beta:0: 0.00% sparsity  (0/128)
# batch_normalization_5/moving_mean:0: 0.00% sparsity  (0/128)
# batch_normalization_5/moving_variance:0: 0.00% sparsity  (0/128)
# dense_2/kernel:0: 50.00% sparsity  (128/256)
# dense_2/bias:0: 0.00% sparsity  (0/2)

# %%
import os
import tempfile

# %%
def get_gzipped_model_size(file):
  # Returns size of gzipped model, in bytes.
  import os
  import zipfile

  _, zipped_file = tempfile.mkstemp('.zip')
  with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
    f.write(file)

  return os.path.getsize(zipped_file)

# %%
converter5 = tf.lite.TFLiteConverter.from_keras_model(stripped_pruned_model)
converter5.optimizations = [tf.lite.Optimize.DEFAULT]
pqat_tflite_model = converter5.convert()
_, pqat_model_file = tempfile.mkstemp('.tflite')
# Save the model.
with open(pqat_model_file, 'wb') as f:
    f.write(pqat_tflite_model)


print('Saved quantized and clustered TFLite model to:', pqat_model_file)

print("Size of gzipped clustered and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pqat_model_file)))
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# Saved quantized and clustered TFLite model to: /tmp/tmprh5up50n.tflite
# Size of gzipped clustered and quantized TFlite model: 1325849.00 bytes
